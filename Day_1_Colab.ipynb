# %%
print("Hello World")
'''
s bnc sbn snb s
scbsjsv
hjcvshvbhjv
hjvhjsvhjs
'''
#fghfvjgvhjgkghjvhjvghcfjcbahjcvsjc jh
name = "Shubham"
last_name='Dhangar'
print(name)
print(type(name))
print (last_name)
print(type(last_name))

age=12
abc = True
percentage= 78.90
print(age)
print(type(age))
print(abc)
print(type(abc))
print(percentage)
print(type(percentage))
print ("My name is",name ,"and last name is ", last_name, "and age is ", age)
# Out:
# Hello World
# Shubham
# <class 'str'>
# Dhangar
# <class 'str'>
# 12
# <class 'int'>
# True
# <class 'bool'>
# 78.9
# <class 'float'>
# My name is Shubham and last name is  Dhangar and age is  12

# %%
num = int(input ("Enter your num: "))
print (num)
print (type(num))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_792/3336616674.py in <cell line: 0>()
# ----> 1 num = int(input ("Enter your num: "))
#       2 print (num)
#       3 print (type(num))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
# Arithmetic Operators

#Addition
a = 5
b = 7
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a**b)
print (a%b)
print (a//b)

# %%
# Comparision Operator

a = 6
b = 6

print (a>b)
print (a<b)
print (a==b)
print (a<=b)
print (a>=b)

# %%
age = 14
print(age > 18 or age < 65)

# %%
# Assignment Operater

a = 5
print (a)
a += 10
#a= a+ 10

print (a)
a -= 4
print (a)
#a= a-4

a *= 5
#a= a*5
print (a)

a /= 5
# a = a/5
print (a)

# %%
text = "Python"
print("P" in text)

# %%
a = 10
b = a
print(a is b)
print (a == b)
print (a is not b)
print (a != b)
print (b)
print (type(a))
print (type(b))

# %%
# Conditional Statements
# if , elif , else

a = 11
b = 10

if (a < b):
 print ("Hello")

elif (a > b):
  print ("Okay")

elif (a == b):
  print ("World")
else:
  print ("Bye")


if(a != b ):
  print ("Kartik")

# %%
for i in range(10):
  print(i)

# %%
for i in range(10):
    if i == 3:
      break
      #continue
      #print(i)
    print(i)

# %%
a = [1,2,3,4,5,6]
for i in a:
  print (i)

# %%
i = 34
while i < 50:
    print(i)
    break
    i += 1

# %% [markdown]
# #Slicing
# # string[start : end : step]

# %%
text = "Python is  a programming language"

print(text[0:3])   # Pyt
print(text[2:])    # thon
print(text[:4])    # Pyth
print(text[-1])    # n (last character)
print(text[::-1])  # Reverse string

# %%
text = "Python is  a programming language"
print(text.upper())  # PYTHON
print(text.lower())  # python

# %%
# strip

text = "  hello "
print(text)
print(text.strip())

# %%
#replace
text = "Hello World"
print(text.replace("World","Python"))

# %%
#split
text = "Python is  a programming language"
print(text.split("a"))

# %%
text = "1,2,3,4,5,4,3,2,3,6,4,1,2,3,2,1,2"
print(text.count("2"))

# %%
text = "Shubham   "
print (len(text))

# %% [markdown]
# #Functions

# %%
#user based non parameters function
def greeting ():
  a=10
  b=20
  print(a+b)
  print ("Hello World")

greeting ()

# %%
#user based  parameters function
def details (First_Name):
  print (f"My name is {First_Name}")
  print ("my Name is ", First_Name)

details("SHubham")
#details()

# %%
#functions with multiple value and return
 #       5, 6
def add (x,y):
  print("The addition of 2 no is :", x+y)
  return x+y

result = add (5,6)
print (result)
add(10,30)

# %%
def greet(name="World"):
    print("Hello", name)

greet()

# %%
#Keyword Arguments Function
def info(name, age, last_name):
    print(name, age,last_name)

info(age=21, name="Kartik" , last_name="Dhangar")
info(age=34, name="Aditya" , last_name="Patil")

# %%
#multiple arguments functions
def add(*names):   #args
    print((names))

add(1,"Shubham",23.09, 23 , True)
add(1,2,3,4,5,6,7,8,9,0)

# %%
#kwargs functions
def display(**details):
    print(details)

display(name="Kartik", age=21,address="Mumbai")
display(name="Kartik", age="Kartik",address="Mumbai")

# %%
#lamba function
add = lambda a, b: a + b
print(add(2, 3))

# %%
# ==============================
# 📌 Q1. Simple Linear Prediction
# y = 2x + 3
# ==============================

x = float(input("Enter value of x: "))
y = 2 * x + 3
print("Predicted y:", y)

# %%
# ==============================
# 📌 Q2. Threshold Classification
# ==============================

temp = float(input("Enter temperature: "))

if temp > 30:
    print("Hot")
else:
    print("Normal")

# %%
# ==============================
# 📌 Q3. Average of Features
# ==============================

nums = []

for i in range(5):
    val = float(input("ENter No"))
    nums.append(val)

avg = sum(nums) / len(nums)
print("Average:", avg)

# %% [markdown]
# # ==============================
#   Q1. Data Type Identification
#  Take an input and print its data type
#  (int, float, or string)
# # ==============================
#
#
# # ==============================
#   Q2. Convert and Add
#  Take two inputs as strings,
# convert them to integers and print sum
# # ==============================
#
#
# # ==============================
#  Q1. User Feature Input
#  Take user input: age, study_hours
#  Print them in formatted sentence
#  ==============================
#
#
# # ==============================
#  📌 Q2. Simple Score Prediction
#  Take marks of 3 subjects as input
#  Print total and average
# # ==============================
#
#
# # ==============================
#  📌 Q3. Formatted Output
#  Take name and accuracy (float)
#  Print: "Model trained by <name> has accuracy <value>%"
# # ==============================
#
# # ==============================
#  Q1. Pass/Fail Prediction
#  If marks >= 40 → "Pass"
#  else → "Fail"
# # ==============================
#
#
# # ==============================
#  📌 Q2. Multi-Class Classification
#  If score >= 80 → "A"
#  elif >= 60 → "B"
#  else → "C"
# # ==============================
#
#
# # ==============================
#  Q3. Risk Detection
#  If age > 60 and bp > 140 → "High Risk"
#  else → "Normal"
# # ==============================

# %% [markdown]
# #OOP

# %%
class Person:

   Name='Shubham'
   L_Name='Dhangar'
   Roll_No=1001
   Barnch="CS"
   print("ambchjabchjab")

object1 = Person()




print(object1.Name, object1.L_Name, object1.Roll_No, object1.Barnch)

# %%
class Dog:
  species = "Canine" # Class Attribute

  def __init__(self, name, age):
    self.name = name # Instance Attribute
    self.age = age # Instance Attribute

#Creating an object of a Dog Class
dog1 = Dog("Buddy", 3)
dog2= Dog("Miky", 7)

print (dog1.name)
print (dog1.age)
print (dog1.species)

# %%
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def animal_name(self, dog, cat):
        self.dog = dog
        self.cat = cat
        print("Dog name:", self.dog)
        print("Cat name:", self.cat)
        print("Dog name of init fun ", self.name)

    def location(self, state, country):
        self.state = state
        self.country = country
        print("State:", self.state)
        print("Country:", self.country)



# Taking input from user
name = input("Enter dog object name: ")
age = int(input("Enter age: "))

dog_value = input("Enter dog name: ")
cat_value = input("Enter cat name: ")

# Creating object
d = Dog(name, age)
print (d.name)
print (d.age)
print (d.species)
# Calling function with user input
d.animal_name(dog_value, cat_value)

d.location("Maharashtra", "India")

# %%
class car:
  def __init__(self, brand):
    self.brand = brand

  def show(self, colour):
    self.colour = colour
    print("Car colour : ", self.colour)
    print("Car Brand : ", self.brand)

  def display(self):
     print("Car colour : ", self.colour)
     print("Car Brand : ", self.brand )

c= car("Toyota")
c.show("Red")
c.display()

# %%
class Details:

  def __init__(self, name, age, height, weight):
    self.name = name
    self.age = age
    self.height = height
    self.weight = weight
    print(f"The name of student is {self.name} and his age is {self.age}")
    print(f"The height of student is {self.height} and weight is {self.weight}" )



  def student(self):
    print(f"The name of student is {self.name} and his age is {self.age}")
    print(f"The height of student is {self.height} and weight is {self.weight}" )

  def person (self, id , roll_no):
    self.id = id
    self.roll_no = roll_no
    print (f"The id of student is {self.id} and roll no is {self.roll_no}and name of that student is {self.name}")




a = Details ("Shubham", 20, 175.67 , 60)
a.student()
a.person(1001, 10)
